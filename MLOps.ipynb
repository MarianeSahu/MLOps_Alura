# %% [markdown]
# # Biblioteca e vaiaveis ambientes

# %%
from textblob import TextBlob

# %% [markdown]
# # Modelo para analise de sentimento

# %%
frase = 'Python é ótimo para Machine Learning'
tb = TextBlob(frase)
tb
tb_en = tb.translate(to = 'en')
tb_en
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-9-9e478515eac5> in <module>()
#       2 tb = TextBlob(frase)
#       3 tb
# ----> 4 tb_en = tb.translate(to = 'en')
#       5 tb_en
#
# /usr/local/lib/python3.7/dist-packages/textblob/blob.py in translate(self, from_lang, to)
#     545         """
#     546         return self.__class__(self.translator.translate(self.raw,
# --> 547                               from_lang=from_lang, to_lang=to))
#     548
#     549     def detect_language(self):
#
# /usr/local/lib/python3.7/dist-packages/textblob/translate.py in translate(self, source, from_lang, to_lang, host, type_)
#      52             tk=_calculate_tk(source),
#      53         )
# ---> 54         response = self._request(url, host=host, type_=type_, data=data)
#      55         result = json.loads(response)
#      56         if isinstance(result, list):
#
# ...

# %%
# !pip install textblob
